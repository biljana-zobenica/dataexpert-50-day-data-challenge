# %% [markdown]
# ## Python and Data Structures - Quiz 4

# %% [markdown]
# ### 1 - What will be the output of the following code?

# %% [raw]
# x = {1, 2, 3}
# x.add(2)
#
# print(len(x))

# %% [markdown]
# 4
#
# 1
#
# 2
#
# 3 ✅

# %% [markdown]
# ### 2 - What is the output of this code?

# %% [raw]
# nums = [1, 2, 3]
#
# print(nums * 2)

# %% [markdown]
# [1, 2, 3, 1, 2, 3]  ✅
#
# Error
#
# [2, 4, 6]
#
# None

# %% [markdown]
# ### 3 - What is the output of this code?

# %% [raw]
# x = 5
# def increment(x):
#     x += 1
#     return x
# increment(x)
# print(x)

# %% [markdown]
# None
#
# 0
#
# 5 ✅
#
# 6

# %% [markdown]
# ### 4 - What is the output of this code?

# %% [raw]
# class Base:
#     def __init__(self):
#         print("Base")
#
# class Derived(Base):
#     def __init__(self):
#         super().__init__()
#         print("Derived")
#
# d = Derived()

# %% [markdown]
# Base ✅
# Derived ✅
#
# Base
#
# Derived
# Base
#
# Derived

# %% [markdown]
# ### 5 - What will be the output of the following code?

# %% [raw]
# def func(x, y=[]):
#     y.append(x)
#     return y
#
# print(func(1))
#
# print(func(2, []))
#
# print(func(3))

# %% [markdown]
# [1]
# [1, 2]
# [1, 2, 3]
#
# [1]
# [2]
# [3]
#
# [1]
# [2]
# [1, 2, 3]
#
# [1]
# [2]
# [1, 3] ✅
