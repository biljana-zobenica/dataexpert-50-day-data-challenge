# %% [markdown]
# ## Machine Learning and AI - Quiz 5

# %% [markdown]
# ### 1 - What is the primary focus of data curation?

# %% [markdown]
# Displaying data visually.
#
# Collecting data from various sources.
#
# Ensuring the quality and usability of data. ✅
#
# Storing data in archives.

# %% [markdown]
# ### 2 - AI-powered data synthesis techniques aim to use sophisticated algorithms to generate new data that mimics existing data.

# %% [markdown]
# True ✅
#
# False

# %% [markdown]
# ### 3 - Which of the following is an example of a data augmentation technique?

# %% [markdown]
# Adding random noise to data ✅
#
# Conducting a statistical analysis
#
# Normalizing data formats
#
# Removing duplicates

# %% [markdown]
# ### 4 - In the context of data synthesis, what is the 'bootstrapping' method?

# %% [markdown]
# Using user feedback to refine synthesis techniques.
#
# Using existing data to generate new hypotheses.
#
# Creating additional samples from existing samples through resampling. ✅
#
# Automatically collecting data from web sources.

# %% [markdown]
# ### 5 - Which of the following is an advanced technique in data augmentation for text datasets?

# %% [markdown]
# Removing punctuation marks
#
# Randomly deleting entire sentences
#
# Rotating words in sentences
#
# Synonym replacement ✅
