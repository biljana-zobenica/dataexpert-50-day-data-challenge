# %% [markdown]
# ## Machine Learning and AI - Quiz 6

# %% [markdown]
# ### 1 - Which component allows RAG to enhance its text generation capabilities?

# %% [markdown]
# Semantic Memory
#
# Retrieval Algorithms ✅
#
# Model Size
#
# Context Length

# %% [markdown]
# ### 2 - In what way can RAG be extended beyond texts?

# %% [markdown]
# By focusing on databases exclusively
#
# By incorporating multimodal data ✅
#
# By using only structured data formats
#
# By limiting its functions to text-only responses

# %% [markdown]
# ### 3 - What is a key challenge in evaluating agent performance?

# %% [markdown]
# Identifying the best training algorithm
#
# Quantifying sheer data volume
#
# Reducing operational costs
#
# Determining failure modes and their impact ✅

# %% [markdown]
# ### 4 - Which of the following techniques helps in fine-tuning RAG models?

# %% [markdown]
# Regular Expression Matching
#
# Agent Simulation
#
# Parameter Freezing
#
# Transfer Learning ✅

# %% [markdown]
# ### 5 - Memory usage in agents can lead to increased processing time, which is always a disadvantage.

# %% [markdown]
# False ✅
#
# True
