# %% [markdown]
# ## Data Pipelines - Quiz 5

# %% [markdown]
# ### 1 - Which of the following techniques is most effective for real-time data ingestion in event-driven architectures?

# %% [markdown]
# Data warehousing
#
# Change Data Capture ✅
#
# batch processing
#
# ETL (Extract, Transform, Load)

# %% [markdown]
# ### 2 - In the context of data ingestion, what does the term "schema evolution" refer to?

# %% [markdown]
# The conversion of data types during the ingestion process.
#
# The ability to adapt to changing data formats without disrupting incoming data flows. ✅
#
# The process of adjusting database schemas based on performance metrics.
#
# The incremental backup of schema definitions over time.

# %% [markdown]
# ### 3 - What is a major challenge in ensuring data quality during schema-on-read ingestion?

# %% [markdown]
# Predictability of data types
#
# Increased storage requirements
#
# Lack of structure before data is queried ✅
#
# Data redundancy issues

# %% [markdown]
# ### 4 - Which aspect of data ingestion most influences system scalability?

# %% [markdown]
# The ingestion rate management ✅
#
# The choice of data format
#
# The profiling of source data
#
# Data compression level

# %% [markdown]
# ### 5 - When handling JSON data during ingestion, which challenge is often encountered due to its flexible schema nature?

# %% [markdown]
# Longer processing times compared to XML.
#
# High memory consumption.
#
# Difficulties in real-time analysis.
#
# Difficulty in enforcing strict data integrity constraints. ✅
