# %% [markdown]
# ## Distributed Computing (Spark, BigQuery, Snowflake) - Quiz 6

# %% [markdown]
# ### 1 - Which layers form the foundation of Snowflake's architecture?

# %% [markdown]
# Database Storage ✅
#
# Cloud Services ✅
#
# Compute (Virtual Warehouses) ✅
#
# Management

# %% [markdown]
# ### 2 - You need to ingest streaming JSON events from an Apache Kafka topic into Snowflake with minimal latency. Which Snowflake service should you configure?

# %% [markdown]
# Data Marketplace subscription
#
# Snowpipe with a Kafka connector ✅
#
# External Table over a GCS bucket
#
# Bulk Load using the COPY command

# %% [markdown]
# ### 3 - Your analytics team runs many concurrent ad‑hoc queries, causing the warehouse to queue. Which setting can you adjust to increase the number of concurrent queries without provisioning a larger warehouse?

# %% [markdown]
# QUERY_TIMEOUT session parameter
#
# AUTO_SUSPEND timeout
#
# RESOURCE_MONITOR credit limit
#
# MAX_CONCURRENCY_LEVEL parameter on the warehouse ✅

# %% [markdown]
# ### 4 - In a complex data architecture, which statement best describes the relationship between Snowflake's storage and compute layers?

# %% [markdown]
# Storage and compute are always tightly coupled
#
# Compute can only be scaled manually
#
# Storage automatically determines compute resources
#
# Storage and compute are completely independent, allowing separate scaling ✅

# %% [markdown]
# ### 5 - Two analysts run the same complex query within a 24‑hour window. The second analyst’s query finishes instantly. Which Snowflake feature is responsible?

# %% [markdown]
# Time Travel
#
# Query Acceleration Service (QAS)
#
# Result Caching ✅
#
# Data Replication
