# %% [markdown]
# ## Data Pipeline - Quiz 1

# %% [markdown]
# ### 1 - Which serialization format is optimal for columnar analytics and reducing storage + read IO?

# %% [markdown]
# JSON
#
# CSV
#
# ORC ✅
#
# Parquet ✅

# %% [markdown]
# Note: JSON and CSV are row-based, while ORC and Parquet are more columnar-base.

# %% [markdown]
# ### 2 - What is the advantage of storing raw (source) data unchanged as a pipeline practice?

# %% [markdown]
# Enables reprocessing and debugging from an authoritative source. ✅
#
# Prevents any future schema changes.
#
# Reduces storage cost dramatically.
#
# Speeds up queries on aggregated views.

# %% [markdown]
# ### 3 - Which pipeline stage is typically responsible for validating schema and basic data quality before downstream processing?

# %% [markdown]
# Extract
#
# Orchestrator
#
# Load
#
# Transform ✅

# %% [markdown]
# ### 4 - Which of the following is the primary benefit of using a schema registry in a pipeline?

# %% [markdown]
# Lower storage costs.
#
# Enforced compatibility and discoverability of schemas. ✅
#
# Faster cluster networking.
#
# Automatic scaling of consumers.
