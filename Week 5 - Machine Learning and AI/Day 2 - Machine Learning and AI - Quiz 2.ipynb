# %% [markdown]
# ## Machine Learning and AI - Quiz 2

# %% [markdown]
# ### 1 - Which of the following scenarios would likely result in high variance?

# %% [markdown]
# Using a complex model with many parameters on a small dataset. ✅
#
# Reducing the number of features in a model.
#
# Using a linear model to fit a quadratic dataset.
#
# Applying regularization to a model.

# %% [markdown]
# ### 2 - Increasing training data will typically decrease both bias and variance.

# %% [markdown]
# True
#
# False ✅

# %% [markdown]
# ### 3 - In which of the following situations would you be most concerned about high bias rather than high variance?

# %% [markdown]
# When using a deep neural network with insufficient training data.
#
# When applying a simple linear regression model to a nonlinear relationship. ✅
#
# When developing a model for a large, complex dataset that is expected to have a variety of patterns.
#
# When creating a recommendation system with limited user data.

# %% [markdown]
# ### 4 - In scenarios where overfitting is a concern, which method is commonly used to address it by effectively balancing bias and variance?

# %% [markdown]
# Feature Scaling
#
# Ensemble Methods ✅
#
# Dimensionality Reduction
#
# Data Augmentation

# %% [markdown]
# ### 5 - In the context of bias-variance trade-off, the "no free lunch" theorem suggests that:

# %% [markdown]
# Higher complexity models always outperform simpler models.
#
# There is always a solution that minimizes both bias and variance perfectly.
#
# Increasing the data quantity will always decrease variance.
#
# No single model performs best for all datasets; performance is context-dependent. ✅
