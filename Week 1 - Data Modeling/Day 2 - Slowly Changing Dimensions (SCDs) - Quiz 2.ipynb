# %% [markdown]
# ## Data Modeling - Slowly Changing Dimensions (SCDs)

# %% [markdown]
# ### 1 - What is a Slowly Changing Dimension (SCD) in data modeling?

# %% [markdown]
# A dimension whose attributes change slowly over time ✅
#
# A type of dimension that does not change over time
#
# A dimension that changes only due to data errors
#
# A dimension that changes rapidly and unpredictably

# %% [markdown]
# ### 2 - Why is it important to model Slowly Changing Dimensions correctly?

# %% [markdown]
# To maintain the idempotency of data pipelines ✅
#
# To speed up the data processing
#
# To keep the database size small
#
# To eliminate all types of data anomalies

# %% [markdown]
# ### 3 - Which of the following is NOT a type of Slowly Changing Dimension?

# %% [markdown]
# Type4
#
# Type2
#
# Type0 ✅
#
# Type3

# %% [markdown]
# ### 4 - What makes Type 2 Slowly Changing Dimensions advantageous?

# %% [markdown]
# They are simple and require the least storage space
#
# They track only the latest value of a dimension
#
# They utilize start and end dates to track changes over time ✅
#
# They do not require any temporal component

# %% [markdown]
# ### 5 - What problem arises from using the 'latest snapshot' approach to SCD?

# %% [markdown]
# It simplifies data warehousing processes
#
# It may lead to incorrect backfill results ✅
#
# It reduces storage costs significantly
#
# It maintains data accuracy over time
