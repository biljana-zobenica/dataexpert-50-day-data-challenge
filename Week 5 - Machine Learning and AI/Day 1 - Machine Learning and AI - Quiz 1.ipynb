# %% [markdown]
# ## Machine Learning and AI - Quiz 1

# %% [markdown]
# ### 1 - The concept of "overfitting" is most commonly associated with which category of machine learning?

# %% [markdown]
# None of the above
#
# Supervised Learning ✅
#
# Unsupervised Learning
#
# Reinforcement Learning

# %% [markdown]
# ### 2 - In Unsupervised Learning, which method is primarily used for dimensionality reduction?

# %% [markdown]
# Decision Trees
#
# Linear Regression
#
# Principal Component Analysis ✅
#
# Support Vector Machines

# %% [markdown]
# ### 3 - Which of the following metrics is most appropriate for evaluating a clustering algorithm?

# %% [markdown]
# Silhouette score ✅
#
# Accuracy
#
# F1 score
#
# Mean squared error

# %% [markdown]
# ### 4 - Which of the following is the main purpose of resampling techniques?

# %% [markdown]
# To ensure data normalization
#
# To create multiple versions of a dataset for model validation ✅
#
# To reduce the dimensionality of the dataset
#
# To visualize the distribution of data

# %% [markdown]
# ### 5 - Which of the following scenarios would MOST benefit from stratified sampling?

# %% [markdown]
# Collecting opinions on a new product from a random group.
#
# Estimating the average height of students in a large university.
#
# Analyzing the prevalence of a rare disease in a population. ✅
#
# Assessing customer satisfaction levels in a retail chain.
