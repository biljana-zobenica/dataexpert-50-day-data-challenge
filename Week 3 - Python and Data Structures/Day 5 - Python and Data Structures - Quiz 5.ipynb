# %% [markdown]
# ## Python and Data Structures - Quiz 5

# %% [markdown]
# ### 1 - In the datetime module, which method retrieves just the date part of a datetime object?

# %% [markdown]
# datetime.date()
#
# datetime.today.date()
#
# datetime.date.today() ✅
#
# datetime.today()

# %% [markdown]
# ### 2 - Which module provides the LRU (least-recently-used) cache decorator out of the box?

# %% [markdown]
# itertools
#
# cachetools
#
# functools ✅
#
# collections

# %% [markdown]
# ### 3 - What is the output of print(0.1 + 0.2 == 0.3)?

# %% [markdown]
# True
#
# Error
#
# None
#
# False ✅

# %% [markdown]
# ### 4 - What is the time complexity of accessing an element in a dictionary?

# %% [markdown]
# O(log n)
#
# O(0)
#
# O(n)
#
# O(1) ✅

# %% [markdown]
# ### 5 - What does the *args syntax in a function definition do?

# %% [markdown]
# Passes a fixed number of arguments.
#
# Accepts a variable number of arguments. ✅
#
# Returns a tuple of arguments.
#
# Forces positional arguments only.
