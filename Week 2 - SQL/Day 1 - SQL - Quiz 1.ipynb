# %% [markdown]
# ## SQL - Quiz 1

# %% [markdown]
# ### 1 - How does cumulation-based analysis differ from aggregation-based analysis in terms of data handling?

# %% [markdown]
# Cumulation-based analysis requires more storage space.
#
# Cumulation-based analysis ignores null or missing data.
#
# Cumulation-based analysis doesn't use SQL.
#
# Cumulation-based analysis focuses on the relationship between datasets over time. ✅

# %% [markdown]
# ### 2 - What is survivorship bias?

# %% [markdown]
# An advanced SQL query optimization technique.
#
# A tendency to ignore previously successful analyses.
#
# A method to filter out inactive data entities.
#
# A type of bias that focuses on successful entities that survive a process. ✅

# %% [markdown]
# ### 3 - What is the purpose of using the 'coalesce' function in the growth accounting table design?

# %% [markdown]
# To remove duplicates from the user ID column.
#
# To retrieve the non-null value between yesterday's and today's data. ✅
#
# To concatenate user IDs and dates into a single column.
#
# To convert date formats between different standards.

# %% [markdown]
# ### 4 - For retention analysis, how can one examine cohorts over time?

# %% [markdown]
# By using the first active date to track users' activity patterns. ✅
#
# By allowing cohort grouping based on geographical location.
#
# By only considering users who make purchases.
#
# By filtering data to exclude inactive days.

# %% [markdown]
# ### 5 - What condition defines a user as 'retained' on a daily basis?

# %% [markdown]
# Their first active date is before today.
#
# Their user ID appears in today's data.
#
# Their user ID is null in the current_day.
#
# Their last active date equals today minus one. ✅
