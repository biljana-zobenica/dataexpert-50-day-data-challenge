# %% [markdown]
# ## Data Modeling - Fact Data Modeling

# %% [markdown]
# ### 1 - Why is fact data typically much larger than dimensional data?

# %% [markdown]
# Fact data records every event a user performs, such as clicks and interactions. ✅
#
# Fact data is collected over a longer period of time compared to dimensional data.
#
# Fact data is stored in multiple formats including text, image, and video.
#
# Fact data includes metadata and audit logs that dimensional data does not have.
