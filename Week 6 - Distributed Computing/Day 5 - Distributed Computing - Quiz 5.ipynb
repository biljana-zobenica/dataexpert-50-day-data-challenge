# %% [markdown]
# ## Distributed Computing (Spark, BigQuery, Snowflake) - Quiz 5

# %% [markdown]
# ### 1 - A table events is partitioned by DATE(event_date) and clustered by user_id. A query filters on event_date and groups by user_id. Which statement best describes the cost impact?

# %% [markdown]
# Clustering reduces the amount of data scanned within each partition, lowering query cost. ✅
#
# Clustering increases storage cost but does not affect query cost.
#
# Clustering adds no benefit because the table is already partitioned.
#
# Clustering only helps when the query contains a JOIN.

# %% [markdown]
# ### 2 - An organization has a flat‑rate reservation of 10,000 slots shared across many projects. A nightly batch job consumes 8,000 slots, causing interactive dashboards to run slowly. Which configuration change can improve fairness without reducing total slots?

# %% [markdown]
# Enable flex slots for the batch project and set a slot‑allocation policy that caps the batch project at 5,000 slots. ✅
#
# Move the batch job to a different region.
#
# Increase max_concurrent_rate on the batch job.
#
# Reduce the batch job’s query_priority to INTERACTIVE.

# %% [markdown]
# ### 3 - A table sales has a row‑level security policy that restricts rows to the requesting user’s region. A dashboard query selects SUM(amount) for the user’s region. How does RLS affect the amount of data scanned?

# %% [markdown]
# BigQuery pushes the RLS filter down to storage, so only rows matching the policy are scanned, reducing cost. ✅
#
# RLS only works for INSERT statements, not SELECT.
#
# RLS forces the query to run in legacy SQL mode, which is less efficient.
#
# It adds a filter that is applied after the data is read, so bytes processed are unchanged.

# %% [markdown]
# ### 4 - A user creates a JavaScript UDF parse_json that extracts a field from a JSON string column. A query over a 5 TB table runs for 3 hours, and the query plan shows a UDF step costing > 80 % of total time. Which action is most likely to improve performance?

# %% [markdown]
# Set udf_timeout_ms to a higher value.
#
# Rewrite the logic using native JSON functions. ✅
#
# Enable allow_large_results.
#
# Increase the query’s max_bytes_billed limit.

# %% [markdown]
# ### 5 - Your organization frequently runs ad-hoc queries on large datasets. You are concerned about the increasing costs. Which strategy will help reduce these costs the most?

# %% [markdown]
# Maintain multiple copies of the same dataset for different teams.
#
# Increase the number of slots your project has allocated.
#
# Use partitioned tables and query only relevant partitions. ✅
#
# Store the results of frequently-used queries in temporary tables.
