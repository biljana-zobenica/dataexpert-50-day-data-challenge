# %% [markdown]
# ## Distributed Computing (Spark, BigQuery, Snowflake) - Quiz 1

# %% [markdown]
# ### 1 - Which of the following best characterises the term "partition tolerance" in the context of the CAP theorem?

# %% [markdown]
# Each node can handle transactions independently of others.
#
# The system remains operational even when some nodes are unable to communicate. ✅
#
# The system must process all requests without delay.
#
# Data must remain consistent across all nodes at all times.

# %% [markdown]
# ### 2 - In what scenario would a distributed system prefer eventual consistency over strong consistency?

# %% [markdown]
# In database management for critical data
#
# When user experience is prioritized ✅
#
# In scenarios requiring immediate data synchronization
#
# In financial transactions

# %% [markdown]
# ### 3 - A distributed system can achieve both high availability and strong consistency simultaneously.

# %% [markdown]
# True
#
# False ✅

# %% [markdown]
# ### 4 - You are designing a system where different teams are responsible for various microservices. A service needs to call another service’s API. Which pattern should you implement to ensure resilience in case the called service fails?

# %% [markdown]
# Singleton Pattern
#
# Observer Pattern
#
# Strategy Pattern
#
# Circuit Breaker Pattern ✅

# %% [markdown]
# ### 5 - A company operates a distributed system where multiple nodes can fail independently. The team wants to ensure that user requests are still processed even if some nodes are down. Which architecture would be most suitable?

# %% [markdown]
# Microservices architecture
#
# Centralized architecture
#
# Master-slave architecture
#
# Peer-to-peer architecture ✅
