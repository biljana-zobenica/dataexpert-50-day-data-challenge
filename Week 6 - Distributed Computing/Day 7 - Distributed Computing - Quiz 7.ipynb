# %% [markdown]
# ## Distributed Computing (Spark, BigQuery, Snowflake) - Quiz 7

# %% [markdown]
# ### 1 - A data‑science team needs sub‑second latency on a high‑concurrency dashboard that runs a join between two 500 GB tables. Which Snowflake feature should they enable to meet this requirement?

# %% [markdown]
# Enable the QAS on the warehouse. ✅
#
# Increase the warehouse size to 8X.
#
# Use Snowpipe to stream data continuously.
#
# Convert the tables to external tables on S3.

# %% [markdown]
# ### 2 - After reviewing a query profile, you notice a “Spill to Local Disk” step that adds significant latency. Which action is most likely to eliminate the spill?

# %% [markdown]
# Increase the warehouse size (more compute). ✅
#
# Disable automatic clustering.
#
# Add a clustering key on the join column.
#
# Reduce the result set size with a LIMIT.

# %% [markdown]
# ### 3 - Snowflake uses a shared-nothing database architecture.

# %% [markdown]
# False
#
# True ✅

# %% [markdown]
# ### 4 - Which of the following can significantly impact the cost efficiency of a Snowflake account?

# %% [markdown]
# Storing historical data in a non-compressed format
#
# Using a single, large virtual warehouse for all operations
#
# Increasing storage automatically every month
#
# Leveraging auto-suspend and auto-resume features ✅

# %% [markdown]
# ### 5 - When examining a poor-performing query, which metric from QUERY_HISTORY or the query profile most directly indicates lack of micro-partition pruning?

# %% [markdown]
# High compilation time
#
# Large bytes scanned / bytes in table ratio ✅
#
# Large number of client connections
#
# High number of result rows returned
