# %% [markdown]
# ## Machine Learning and AI - Quiz 3

# %% [markdown]
# ### 1 - What are some common methods used for hyperparameter tuning?

# %% [markdown]
# Grid search ✅
#
# Random search ✅
#
# None of the options
#
# Bayesian optimization ✅

# %% [markdown]
# ### 2 - Hyper parameters are parameters that are learned from the training data during the learning process.

# %% [markdown]
# False ✅
#
# True

# %% [markdown]
# ### 3 - What is the role of cross-validation in hyperparameter tuning?

# %% [markdown]
# To improve model interpretability
#
# To estimate the model's accuracy on unseen data ✅
#
# To increase dataset size
#
# To train the model faster

# %% [markdown]
# ### 4 - Which of the following loss functions is commonly used in classification tasks?

# %% [markdown]
# Log-Cosh Loss
#
# Mean Squared Error (MSE)
#
# Cross-Entropy Loss ✅
#
# Hinge Loss

# %% [markdown]
# ### 5 - What is a key limitation of K-Means clustering?

# %% [markdown]
# It is sensitive to the initial placement of centroids.
#
# It scales well with large datasets.
#
# It requires a pre-defined number of clusters. ✅
#
# It can handle nonspherical clusters.
