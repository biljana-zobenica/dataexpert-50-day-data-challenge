# %% [markdown]
# ## Data Modeling - Cumulative Data

# %% [markdown]
# ### 1 - What are 'struct' and 'array' considered as in dimensional data modeling?

# %% [markdown]
# They are complex data types ✅
#
# They are simple aggregations
#
# They are coding structures
#
# They are basic data types

# %% [markdown]
# ### 2 - Which of the following is a characteristic of a slowly changing dimension?

# %% [markdown]
# It is time-dependent ✅
#
# It lacks historical data
#
# It never changes
#
# It changes frequently

# %% [markdown]
# ### 3 - Your analytics team at a fast-growing e-commerce company is tasked with building a unified cumulative sales dashboard by merging monthly and quarterly sales datasets. However, both datasets have missing months due to occasional pipeline delays. To ensure stakeholders receive an accurate and gap-free report, which conceptual approach should your team use to merge these datasets?

# %% [markdown]
# Use a full outer join combined with COALESCE-like logic to merge all months and fill missing values from either dataset ✅
#
# Cross join the datasets and filter for matching months afterward
#
# Use a left join from the monthly dataset to the quarterly dataset, filling missing quarterly data only
#
# Use an inner join to include only months present in both datasets, skipping months with missing data

# %% [markdown]
# ### 4 - What is the purpose of the cumulative table design in data modeling?

# %% [markdown]
# To hold onto all dimensions that ever existed ✅
#
# To sort data in ascending order
#
# To eliminate duplicate data completely
#
# To remove all historical data

# %% [markdown]
# ### 5 - In the context of dimensional data modeling, who would likely benefit the most from an OLAP cube?

# %% [markdown]
# Software Engineers
#
# Customer Support Representatives
#
# Financial Accountants
#
# Data Scientists and Analysts ✅

# %% [markdown]
# ### 6 - What is a potential drawback of cumulative table design?

# %% [markdown]
# It relies on yesterday's data for continuity ✅
#
# It's easy to backfill parallelly
#
# It cannot handle historical analysis
#
# It cannot store user activities
