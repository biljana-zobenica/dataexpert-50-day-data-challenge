# %% [markdown]
# ## Data Pipelines - Quiz 3

# %% [markdown]
# ### 1 - Which of the following best describes change data capture (CDC)?

# %% [markdown]
# Capturing and recording each change in a source system. ✅
#
# Compressing data for storage.
#
# Aggregating data at regular intervals.
#
# Transforming unstructured data into structured format.

# %% [markdown]
# ### 2 - CDC relies on triggers within the database to function effectively.

# %% [markdown]
# False
#
# True ✅

# %% [markdown]
# ### 3 - When implementing CDC, which of the following options can potentially lead to data inconsistency?

# %% [markdown]
# Using transaction logs for tracking changes.
#
# Utilizing a timestamp for versioning.
#
# Not handling duplicate messages correctly during data synchronization. ✅
#
# Regularly purging old change records.

# %% [markdown]
# ### 4 - CDC only tracks row-level changes, not changes to the structure of a database.

# %% [markdown]
# True
#
# False ✅

# %% [markdown]
# ### 5 - In a CDC implementation, which of the following methods is most likely to increase the load on a source database?

# %% [markdown]
# Snapshotting
#
# Data replication
#
# Change logs
#
# Triggers ✅
