# %% [markdown]
# ## Python and Data Structures - Quiz 3

# %% [markdown]
# ### 1 - What is the output of
# print("Hello, World!")?

# %% [markdown]
# "Hello, World!"
#
# Hello, World! ✅
#
# 'Hello, World!'
#
# Hello World

# %% [markdown]
# ### 2 - Which of the following statements will result in a TypeError?

# %% [markdown]
# '2' + '5'
#
# '2' * 5
#
# '2' + 5 ✅
#
# len(5) ✅

# %% [markdown]
# ### 3 - What will the output of the following code be?

# %% [raw]
# a = [1, 2]
#
# b = a
#
# b[0] = 3
#
# print(a)

# %% [markdown]
# [3, 2] ✅
#
# [3, 1, 2]
#
# [1, 2, 3]
#
# [2, 3]

# %% [markdown]
# ### 4 - What does the following code print?

# %% [raw]
# a = {1, 2}
# a.add(a)
#
# print(a)

# %% [markdown]
# {1, 2}
#
# {{1,2}, {1,2}
#
# Error ✅
#
# {1, 2, 1, 2}

# %% [markdown]
# ### 5 - What is the result of print(True + True)?

# %% [markdown]
# Error
#
# True
#
# 2 ✅
#
# True True
