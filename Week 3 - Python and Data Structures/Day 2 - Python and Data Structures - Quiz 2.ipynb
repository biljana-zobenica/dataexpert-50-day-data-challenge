# %% [markdown]
# ## Python and Data Structures - Quiz 2

# %% [markdown]
# ### 1 - Which of the following data structures is most efficient for implementing a priority queue?

# %% [markdown]
# Hash Table
#
# Array
#
# Binary Heap ✅
#
# Linked List

# %% [markdown]
# ### 2 - Which of the following data structures can be used to implement a recursive function?

# %% [markdown]
# Stack ✅
#
# Linked List
#
# Queue
#
# Graph

# %% [markdown]
# ### 3 - Which of the following trees is always balanced?

# %% [markdown]
# Red-Black Tree ✅
#
# Binary Tree
#
# Binary Search Tree
#
# AVL Tree ✅

# %% [markdown]
# ### 4 - Which of the following is NOT a characteristic of a stack?

# %% [markdown]
# Push and Pop operations
#
# Last In First Out (LIFO)
#
# Random Access ✅
#
# Dynamic Size

# %% [markdown]
# ### 5 - Which data structure is best for implementing undo functionality in an application?

# %% [markdown]
# Array
#
# Queue
#
# Linked List
#
# Stack ✅
