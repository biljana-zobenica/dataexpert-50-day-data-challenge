# %% [markdown]
# ## Distributed Computing (Spark, BigQuery, Snowflake) - Quiz 2

# %% [markdown]
# ### 1 - A team is implementing a distributed file system that supports atomic operations to ensure that any changes to files are completed entirely or not at all. Which operation would this best describe?

# %% [markdown]
# Append
#
# Write ✅
#
# Read
#
# None of the above

# %% [markdown]
# ### 2 - In distributed file systems that implement consistent hashing, adding new nodes will always require reallocation of all existing data across the new nodes.

# %% [markdown]
# False ✅
#
# True

# %% [markdown]
# ### 3 - In a distributed file system, you are tasked with implementing a mechanism to handle file access control where multiple users may simultaneously access large files. Which technique should be prioritized?

# %% [markdown]
# Write-Ahead Logging
#
# Distributed Mutex Locks
#
# Single Lock Mechanism
#
# Multi-Version Concurrency Control ✅

# %% [markdown]
# ### 4 - Your distributed file system needs to optimize data transfer for large files over a wide-area network (WAN). Which of the following techniques would likely be the most effective?

# %% [markdown]
# Callbacks for Asynchronous Processing
#
# Distributed Caching
#
# Load Balancing
#
# Data Compression and Deduplication ✅

# %% [markdown]
# ### 5 - In a distributed file system with strong consistency, latency is typically reduced because all nodes must acknowledge updates before they are committed.

# %% [markdown]
# False ✅
#
# True
