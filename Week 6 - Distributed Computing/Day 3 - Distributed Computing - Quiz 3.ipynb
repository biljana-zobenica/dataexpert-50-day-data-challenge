# %% [markdown]
# ## Distributed Computing (Spark, BigQuery, Snowflake) - Quiz 3

# %% [markdown]
# ### 1 - Which of the following best describes the purpose of Spark's Catalyst Optimizer?

# %% [markdown]
# Shuffle data partitioning
#
# Distributed task scheduling
#
# Memory management
#
# Query plan optimization and code generation ✅

# %% [markdown]
# ### 2 - What is the primary challenge addressed by Spark's Adaptive Query Execution (AQE)?

# %% [markdown]
# Garbage collection overhead
#
# Network latency
#
# Static query planning limitations ✅
#
# Shuffle data skew

# %% [markdown]
# ### 3 - What happens when you run a spark.sql("SELECT * FROM table WHERE date > '2025-12-17'") query on an unpartitioned table?

# %% [markdown]
# Only metadata is checked; no data is scanned
#
# The query returns all rows without filtering
#
# The query fails due to missing partitioning
#
# A full table scan is performed, and only rows matching the condition are returned ✅

# %% [markdown]
# ### 4 - When using the JOIN operation in Spark SQL, under what circumstances would you find a Broadcast Hash Join to be more efficient than a Shuffle Hash Join?

# %% [markdown]
# When joining two very large datasets.
#
# When both datasets have a large number of null values.
#
# When one of the datasets is significantly smaller than the other. ✅
#
# When both datasets are partitioned in the same way.

# %% [markdown]
# ### 5 - A SQL expression uses COALESCE extensively and query is slow. What optimizer behavior impacts this?

# %% [markdown]
# COALESCE disables vectorized parquet reader
#
# COALESCE triggers full shuffle
#
# COALESCE forces recomputation of entire table
#
# Catalyst converts COALESCE to first non-null via CASE and may hinder predicate pushdown if over-used ✅
