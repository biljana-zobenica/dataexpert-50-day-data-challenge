# %% [markdown]
# ## Python and Data Structures - Quiz 1

# %% [markdown]
# ### 1 - What does Big O notation specifically describe?

# %% [markdown]
# The exact running time of an algorithm.
#
# The space complexity of an algorithm.
#
# The average case scenario for an algorithm.
#
# The upper bound of an algorithm's time complexity. ✅

# %% [markdown]
# ### 2 - Consider the nested loops like so:

# %% [raw]
# for i in range(1, n):
#     for j in range(1, i):
#         # some constant time operation
#         pass

# %% [markdown]
# ### What is the time complexity of this code?

# %% [markdown]
# O(2 * n)
#
# O(n^2) ✅
#
# O(n)
#
# O(n log n)

# %% [markdown]
# ### 3 - Which of the following algorithms has the best time complexity as input size increases?

# %% [markdown]
# O(n log n) ✅
#
# O(n^2)
#
# O(2^n)
#
# O(n^3)

# %% [markdown]
# ### 4 - What is the Big O notation for the following function?

# %% [raw]
# f(n) = 5n^3 + 3n^2 + 2n + 1

# %% [markdown]
# O(n^3) ✅
#
# O(3^n)
#
# O(n)
#
# O(n^2)

# %% [markdown]
# ### 5 - What is the time complexity of finding an element in an unsorted array using a linear search?

# %% [markdown]
# O(1)
#
# O(n ^ 2)
#
# O(n log n)
#
# O(n) ✅
