# %% [markdown]
# ## Machine Learning and AI - Quiz 4

# %% [markdown]
# ### 1 - What role do guardrails play in AI systems?

# %% [markdown]
# They eliminate the need for user feedback.
#
# They prevent models from producing harmful or undesirable outputs. ✅
#
# They streamline data ingestion.
#
# They improve model training speeds.

# %% [markdown]
# ### 2 - User feedback is limited in its ability to inform AI model improvements.

# %% [markdown]
# True ✅
#
# False

# %% [markdown]
# ### 3 - Model optimization techniques can potentially reduce the accuracy of the predictions made by an AI model.

# %% [markdown]
# True ✅
#
# False

# %% [markdown]
# ### 4 - Which of the following is a common performance metric used to evaluate inference efficiency?

# %% [markdown]
# Model size
#
# Training time
#
# Latency ✅
#
# Accuracy

# %% [markdown]
# ### 5 - What does model optimization in inference entail?

# %% [markdown]
# Implementing multiple models for a single task.
#
# Modifying the model architecture to increase complexity.
#
# Focusing solely on training more data.
#
# Reducing model size while maintaining performance. ✅
