# %% [markdown]
# ## Data Pipelines - Quiz 4

# %% [markdown]
# ### 1 - Orchestration frameworks eliminate the need for monitoring and alerting because they automatically handle all errors.

# %% [markdown]
# True
#
# False ✅

# %% [markdown]
# ### 2 - When using a workflow management tool like Apache Airflow, what is the purpose of an operator?

# %% [markdown]
# To monitor the performance of running tasks.
#
# To schedule the execution of workflows at fixed intervals.
#
# To define specific actions or tasks to be performed in a workflow. ✅
#
# To provide a user interface for managing workflows.

# %% [markdown]
# ### 3 - Which of the following is a common drawback of using a microservices architecture for workflow orchestration?

# %% [markdown]
# Increased flexibility and scalability
#
# Complexity in inter-service communication and monitoring ✅
#
# Simplified deployments and updates
#
# Enhanced fault isolation

# %% [markdown]
# ### 4 - What is a crucial consideration when implementing a workflow for data pipelines that require strict compliance with regulations (e.g., GDPR)?

# %% [markdown]
# Minimizing the number of orchestration tools used.
#
# Ensuring high throughput and low latency.
#
# Relying solely on automated error handling.
#
# Including data encryption and access controls. ✅

# %% [markdown]
# ### 5 - Which of the following statements best describes the concept of "data drift" in workflow management?

# %% [markdown]
# Variations in the input data that can affect task outcomes. ✅
#
# The gradual accumulation of data in storage systems.
#
# Changes in data processing speeds over time.
