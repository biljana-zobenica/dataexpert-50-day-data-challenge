# %% [markdown]
# ## SQL - Quiz 7

# %% [markdown]
# ### 1 - Which SQL construct can be used to transform rows into columns without using vendor‑specific PIVOT syntax?

# %% [markdown]
# UNION ALL with ROW_NUMBER()
#
# FULL OUTER JOIN on a derived table
#
# CTE with LAG()
#
# GROUP BY with CASE expressions ✅

# %% [markdown]
# ### 2 - Which of the following returns rows that appear in both tables TABLE_A and TABLE_B but only once, regardless of duplicates in the source tables?

# %% [markdown]
# SELECT * FROM TABLE_A INTERSECT SELECT * FROM TABLE_B ✅
#
# SELECT * FROM TABLE_A EXCEPT SELECT * FROM TABLE_B
#
# SELECT * FROM TABLE_A A INNER JOIN TABLE_B B ON A.id = B.id
#
# SELECT * FROM TABLE_A UNION SELECT * FROM TABLE_B

# %% [markdown]
# ### 3 - What is the output of LAG(salary, 1, 0) in a window function when the first row has no preceding value?

# %% [markdown]
# 0 ✅
#
# The first row’s salary
#
# NULL
#
# 1

# %% [markdown]
# ### 4 - What is the result of ROW_NUMBER() when there are duplicate values and no PARTITION BY?

# %% [markdown]
# Skipped numbers after duplicates.
#
# Consecutive numbers regardless of duplicates. ✅
#
# Error.
#
# Same number for duplicates.

# %% [markdown]
# ### 5 - Which query will not use an index on the Name column? (Assume there is a index on Name )

# %% [markdown]
# SELECT * FROM Users WHERE Name LIKE 'Jo%';
#
# SELECT Name FROM Users WHERE Name = 'John';
#
# SELECT * FROM Users WHERE Name = 'John';
#
# SELECT * FROM Users WHERE Name LIKE '%ohn'; ✅
