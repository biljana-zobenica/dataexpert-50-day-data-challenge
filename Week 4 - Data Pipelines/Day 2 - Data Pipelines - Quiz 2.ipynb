# %% [markdown]
# ## Data Pipelines - Quiz 2

# %% [markdown]
# ### 1 - Which of the following is not a challenge in stream processing pipelines?

# %% [markdown]
# Watermarks for handling delays
#
# Event time vs. processing time
#
# Fixed batch intervals ✅

# %% [markdown]
# ### 2 - Which of the following best describes the lambda architecture?

# %% [markdown]
# A batch-only processing model
#
# A hybrid data processing architecture combining batch and stream processing ✅
#
# A real-time streaming-only system
#
# A database indexing technique

# %% [markdown]
# ### 3 - In the context of lambda architecture, what is the primary role of the speed layer?

# %% [markdown]
# To handle real-time data with low latency ✅
#
# To manage metadata
#
# To serve precomputed batch views
#
# To store historical data

# %% [markdown]
# ### 4 - What is the primary purpose of in-memory processing in data pipelines?

# %% [markdown]
# To compress data permanently
#
# To reduce disk usage
#
# To increase data redundancy
#
# To write data to memory between pipeline steps for faster access ✅

# %% [markdown]
# ### 5 - Which service is used to orchestrate complex data workflows with task dependencies?

# %% [markdown]
# BigQuery
#
# Pub/Sub
#
# Apache Spark
#
# Apache Airflow ✅
