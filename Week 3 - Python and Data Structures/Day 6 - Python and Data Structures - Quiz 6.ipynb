# %% [markdown]
# ## Python and Data Structures - Quiz 6

# %% [markdown]
# ### 1 - What is the result of sum(x for x in range(5))?

# %% [markdown]
# 10 ✅
#
# 15
#
# 5
#
# 50

# %% [markdown]
# ### 2 - Which of these will raise a StopIteration exception?

# %% [markdown]
# next((x for x in [])) ✅
#
# sum((x for x in []))
#
# list((x for x in []))
#
# None of the options

# %% [markdown]
# ### 3 - Which statement about memory usage is true?

# %% [markdown]
# Both allocate the same amount of memory.
#
# Generators keep all results in memory after creation.
#
# Generators produce items lazily, so they use less memory for large sequences. ✅
#
# List comprehensions always use less memory than generators

# %% [markdown]
# ### 4 - Which of the following reliably creates a shallow copy of a list a?

# %% [markdown]
# b = list(a) ✅
#
# b = a
#
# b = a[:] ✅
#
# import copy; b = copy.copy(a) ✅

# %% [markdown]
# ### 5 - What does this generator expression produce?
#
# gen = (i*i for i in range(3))
#
# print(list(gen) + list(gen))

# %% [markdown]
# [0,1,4,0,1,4]
#
# []
#
# [0,1,4] ✅
#
# Raises StopIteration
