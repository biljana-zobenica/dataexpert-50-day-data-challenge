# %% [markdown]
# ## Data Pipelines - Quiz 6

# %% [markdown]
# ### 1 - Which security principle focuses on the concept of least privilege in data governance?

# %% [markdown]
# Ensuring maximum data exposure for auditing.
#
# Granting users only the permissions necessary to perform their assigned tasks. ✅
#
# Defining roles based on job titles rather than functions.
#
# Implementing completely open data access models.

# %% [markdown]
# ### 2 - What is a common pitfall of relying solely on metrics for monitoring data pipelines?

# %% [markdown]
# Difficulty in scaling metrics
#
# Complexity of data ingestion
#
# Lack of context around system performance ✅
#
# High overhead costs

# %% [markdown]
# ### 3 - What is a primary benefit of implementing data encryption at the application level compared to encryption at the database level?

# %% [markdown]
# Enhanced security through end-to-end encryption before data is stored. ✅
#
# Reduced complexity in key management.
#
# Simpler implementation and management.
#
# Lower computational overhead during data processing.

# %% [markdown]
# ### 4 - Backpressure in a streaming system is best observable by monitoring which of these together?

# %% [markdown]
# Uptime of producer service
#
# Downstream processing latency ✅
#
# Consumer lag, and, queue length ✅
#
# Number of producer threads

# %% [markdown]
# ### 5 - What is the principal benefit of integrating data governance with CI/CD and infrastructure-as-code?

# %% [markdown]
# Slower deployments.
#
# Making governance optional for developers.
#
# Removing need for data catalogs.
#
# Embedding policy checks, schema validation into the deployment pipeline, ensuring governance is applied consistently and early. ✅
