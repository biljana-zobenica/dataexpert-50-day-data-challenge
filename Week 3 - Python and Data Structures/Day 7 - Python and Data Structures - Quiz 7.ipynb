# %% [markdown]
# ## Python and Data Structure - Quiz 7

# %% [markdown]
# ### 1 - Which of these will make attribute access faster for many instances of a class?

# %% [markdown]
# Using dict directly
#
# Defining slots in the class ✅
#
# Storing attributes in a nested dict
#
# Using property decorators for all attributes

# %% [markdown]
# ### 2 - What is output?

# %% [raw]
# a = [1, 2, 3]
# b = (a.append(4), a)[1]
#
# print(b)

# %% [markdown]
# Raises TypeError
#
# [1, 2, 3]
#
# [1, 2, 3, 4] ✅
#
# []

# %% [markdown]
# ### 3 - What is output?

# %% [raw]
# def g():
#     try:
#         return 1
#     finally:
#         return 2
#
# print(g())

# %% [markdown]
# 2 ✅
#
# None
#
# 1
#
# Raises exception

# %% [markdown]
# ### 4 - What is the output?

# %% [raw]
# def a():
#     yield from []
#     return 42
# g = a()
# try:
#     next(g)
# except StopIteration as e:
#     print(e.value)

# %% [markdown]
# 42 ✅
#
# 0
#
# Raises RuntimeError
#
# Raises StopIteration

# %% [markdown]
# ### 5 - What is the output?

# %% [raw]
# a = [1,2,3]
# b = a
# a = a + [4]
#
# print(b)

# %% [markdown]
# [4]
#
# Raises TypeError
#
# [1,2,3,4]
#
# [1,2,3] ✅
